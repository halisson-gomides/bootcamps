# %% [markdown]
# <a href="https://colab.research.google.com/github/halisson-gomides/bootcamps/blob/main/X_FNTU_2025/API_especiais_consumindo_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  API de dados abertos do módulo de Transferências Especiais do Transferegov

# %% [markdown]
#  ### O que é uma API?

# %% [markdown]
# Imagine que você está em um restaurante. Você é o **cliente**, a cozinha é onde a comida é feita (um sistema complexo com chefs, ingredientes e utensílios), e o **garçom** é quem leva seu pedido (ex: "Eu quero um bife com batatas fritas") para a cozinha e traz a comida pronta de volta para você. Você não precisa saber como o chef prepara o bife, apenas que ele virá conforme o pedido.
#
# Uma **API** (Application Programming Interface) é como esse **garçom, mas para programas de computador**.
#
# É um conjunto de **regras e protocolos** que permite que diferentes aplicativos ou sistemas conversem entre si de forma organizada e segura. Pense nessas regras como um "contrato": ambos os lados (o programa que pede e o que responde) precisam seguir as regras para a comunicação funcionar. Um programa pode "pedir" informações (um request) ou "solicitar" uma tarefa a outro programa usando a API, sem precisar saber como o outro programa funciona por dentro, qual a linguagem de programação utilizada ou o sistema operacional.

# %% [markdown]
# ### Para que serve?

# %% [markdown]
# 1. **Conectar Programas**: Permite que um aplicativo use informações ou funções de
# outro. Pense em um aplicativo de previsão do tempo no seu celular: ele usa uma API para buscar os dados mais recentes de um serviço central de meteorologia (como o INMET). O aplicativo faz uma requisição para a API do serviço de meteorologia, especificando a localização do usuário, e a API retorna os dados da previsão do tempo formatados para o aplicativo exibir. Isso evita que o desenvolvedor do app do tempo tenha que coletar e processar dados meteorológicos diretamente.
#
# 2. **Facilitar a Criação de Apps**: Desenvolvedores não precisam criar tudo do zero. Se precisam de um mapa em seu aplicativo, podem usar a API de um serviço de mapas já existente como o Google Maps API ou Mapbox API. Eles fornecem as ferramentas para exibir mapas, adicionar marcadores, calcular rotas, etc. Se precisam processar pagamentos online, usam a API de um sistema de pagamento como o Stripe API ou PayPal API, que cuidam da segurança e da complexidade das transações financeiras. Isso economiza tempo e recursos, permitindo que os desenvolvedores se concentrem na funcionalidade principal do aplicativo.
#
# 3. **Combinar Serviços**: Permite criar coisas novas juntando funcionalidades de diferentes fontes. Um site de viagens, por exemplo, pode usar APIs para buscar informações de voos (usando a API da Skyscanner ou Amadeus), hotéis (usando a API da Booking.com ou Expedia) e mapas (usando a API do Google Maps), tudo em um só lugar. O site faz requests para cada uma dessas APIs, combina os dados recebidos e apresenta ao usuário uma visão completa da viagem.

# %% [markdown]
# ### Exemplos Práticos

# %% [markdown]
# * **Login com Redes Sociais**: Quando você clica em "Login com Google" ou "Login com Facebook" em um site, o site está usando a API do Google ou Facebook para autenticar sua identidade.
# * **Integração com Calendários**: Um aplicativo de agendamento pode usar a API do Google Calendar ou Outlook Calendar para sincronizar seus compromissos.
# * **Chatbots**: Chatbots usam APIs para entender a linguagem natural do usuário e fornecer respostas relevantes.

# %% [markdown]
# ## Vamos praticar!

# %% [markdown]
# ### Configuração do Ambiente

# %%
! pip list | grep -E 'pandas|requests|urllib3|unidecode'
# Out:
# geopandas                             1.0.1
# pandas                                2.2.2
# pandas-datareader                     0.10.0
# pandas-gbq                            0.28.0
# pandas-stubs                          2.2.2.240909
# requests                              2.32.3
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# sklearn-pandas                        2.2.0
# text-unidecode                        1.3
# urllib3                               2.4.0

# %%
# %%capture
# Caso a célula acima não gere nenhum retorno ou na lista retornada
# não conste uma ou mais das bilibotecas importadas na próxima célula,
# executar essa célula
# !pip install pandas requests urllib3 unidecode

# %%
import requests
import urllib3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from unidecode import unidecode
from io import StringIO

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.min_rows', 500)
pd.set_option('display.expand_frame_repr', True)

# %% [markdown]
# ### Funções úteis

# %%
def api_request(method, url, headers=None, params=None, data=None, json=None, resp_type='json', timeout=10):
    """
    Realiza uma requisição a uma API.

    Args:
        method: O método HTTP da requisição (GET, POST, PUT, DELETE, etc.).
        url: A URL da API.
        headers: Um dicionário com os headers da requisição.
        params: Um dicionário com os parâmetros da query string.
        data: Os dados da requisição (para métodos como POST e PUT).
        json: Os dados da requisição em formato JSON (para métodos como POST e PUT).
        timeout: O tempo limite da requisição em segundos.
        resp_type: O tipo de resposta desejado (json ou text).

    Returns:
        Um objeto Response do requests ou None em caso de erro.
    """
    try:
        response = requests.request(method, url, headers=headers, params=params, data=data, json=json, timeout=timeout)
        response.raise_for_status()  # Levanta uma exceção para status codes de erro (4xx ou 5xx)
        if resp_type == 'json':
            return response.json()
        elif resp_type == 'text':
            return response.text
        return response
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição: {e.__repr__()}")
        return None


def millions_formatter(x, pos):
  return f'{x/1_000_000:.1f} Mi'

# %% [markdown]
# ### Requisição a API - Transferências Especiais

# %%
# Transferencias Especiais - Plano de ação Especiais
api_url = "https://api.transferegov.gestao.gov.br/transferenciasespeciais/plano_acao_especial"
ano_inicial = 2023
ano_final = 2024
qtd_pgs = 20
qtd_por_pag = 1000
lst_anos = [_i for _i in range(ano_inicial,ano_final + 1)]
lst_pgs = [_i for _i in range(qtd_pgs)]
df_paes_raw = pd.DataFrame()

for ano in lst_anos:
  for page in lst_pgs:
    api_params = {
        'ano_plano_acao': f'eq.{ano}',
        'offset': (page * qtd_por_pag),
        'limit': qtd_por_pag
    }
    result = api_request("GET", api_url, params=api_params)
    df_result = pd.DataFrame.from_dict(result, orient='columns')
    if df_result.empty:
      print('*'*100)
      break
    df_paes_raw = pd.concat([df_paes_raw, df_result])
    print(f"Ano: {ano:<5} Pg. {page:<5}- Qtd. Registros: {len(df_paes_raw.loc[df_paes_raw['ano_plano_acao'] == ano])}")
  else:
    print('*'*100)


print(f"\nTotal de linhas: {len(df_paes_raw)}\n")
df_paes_raw.head()
# Out:
# Ano: 2023  Pg. 0    - Qtd. Registros: 1000
# Ano: 2023  Pg. 1    - Qtd. Registros: 2000
# Ano: 2023  Pg. 2    - Qtd. Registros: 3000
# Ano: 2023  Pg. 3    - Qtd. Registros: 4000
# Ano: 2023  Pg. 4    - Qtd. Registros: 5000
# Ano: 2023  Pg. 5    - Qtd. Registros: 6000
# Ano: 2023  Pg. 6    - Qtd. Registros: 7000
# Ano: 2023  Pg. 7    - Qtd. Registros: 8000
# Ano: 2023  Pg. 8    - Qtd. Registros: 9000
# Ano: 2023  Pg. 9    - Qtd. Registros: 9273
# ****************************************************************************************************
# Ano: 2024  Pg. 0    - Qtd. Registros: 1000
# Ano: 2024  Pg. 1    - Qtd. Registros: 2000
# Ano: 2024  Pg. 2    - Qtd. Registros: 3000
# Ano: 2024  Pg. 3    - Qtd. Registros: 4000
# Ano: 2024  Pg. 4    - Qtd. Registros: 5000
# Ano: 2024  Pg. 5    - Qtd. Registros: 6000
# Ano: 2024  Pg. 6    - Qtd. Registros: 7000
# Ano: 2024  Pg. 7    - Qtd. Registros: 8000
# Ano: 2024  Pg. 8    - Qtd. Registros: 9000
# Ano: 2024  Pg. 9    - Qtd. Registros: 10000
# Ano: 2024  Pg. 10   - Qtd. Registros: 10934
# ****************************************************************************************************
#
# Total de linhas: 20207
#    id_plano_acao codigo_plano_acao  ano_plano_acao modalidade_plano_acao  \
# 0          33975   09032023-033975            2023              Especial
# 1          36687   09032023-036687            2023              Especial
# 2          36909   09032023-036909            2023              Especial
# 3          30803   09032023-030803            2023              Especial
# 4          30804   09032023-030804            2023              Especial
#
#   situacao_plano_acao cnpj_beneficiario_plano_acao  \
# 0            IMPEDIDO               08764284000102
# 1            IMPEDIDO               32147670000121
# 2            IMPEDIDO               92963560000160
# 3              CIENTE               05990437000133
# 4              CIENTE               05989116000119
#
#   nome_beneficiario_plano_acao uf_beneficiario_plano_acao  \
# 0    MUNICIPIO DE SANTA HELENA                         PB
# 1                    SAQUAREMA                         RJ
# 2    MUNICIPIO DE PORTO ALEGRE                         RS
# 3        MUNICIPIO DE CALCOENE                         AP
# 4           MUNICIPIO DE AMAPA                         AP
#
#   codigo_banco_plano_acao  codigo_situacao_dado_bancario_plano_acao  \
# 0                    None                                       NaN
# 1                    None                                       NaN
# 2                    None                                       NaN
# 3                     001                                       4.0
# 4                     001                                       4.0
#
#   nome_banco_plano_acao  numero_agencia_plano_acao dv_agencia_plano_acao  \
# 0                  None                        NaN                  None
# 1                  None                        NaN                  None
# 2                  None                        NaN                  None
# 3       Banco do Brasil                     3985.0                     3
# 4       Banco do Brasil                     3985.0                     3
#
#    numero_conta_plano_acao dv_conta_plano_acao  \
# 0                      NaN                None
# 1                      NaN                None
# 2                      NaN                None
# 3                  20324.0                   6
# 4                  20325.0                   4
#
#   nome_parlamentar_emenda_plano_acao ano_emenda_parlamentar_plano_acao  \
# 0                    Wilson Santiago                              2023
# 1                     Lourival Gomes                              2023
# 2                         Bibo Nunes                              2023
# 3                    Davi Alcolumbre                              2023
# 4                    Davi Alcolumbre                              2023
#
#   codigo_parlamentar_emenda_plano_acao  \
# 0                                 1283
# 1                                 3861
# 2                                 3920
# 3                                 3787
# 4                                 3787
#
#    sequencial_emenda_parlamentar_plano_acao  \
# 0                                         9
# 1                                        13
# 2                                         1
# 3                                         2
# 4                                         2
#
#   numero_emenda_parlamentar_plano_acao  \
# 0                         202312830009
# 1                         202338610013
# 2                         202339200001
# 3                         202337870002
# 4                         202337870002
#
#   codigo_emenda_parlamentar_formatado_plano_acao  \
# 0                   202312830009-Wilson Santiago
# 1                    202338610013-Lourival Gomes
# 2                        202339200001-Bibo Nunes
# 3                   202337870002-Davi Alcolumbre
# 4                   202337870002-Davi Alcolumbre
#
#   codigo_descricao_areas_politicas_publicas_plano_acao  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  15-Urbanismo / 451-Infraestrutura Urbana , 15-...
# 4           15-Urbanismo / 451-Infraestrutura Urbana
#
#        descricao_programacao_orcamentaria_plano_acao  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3            1007 , 1011 , 1012 , 1013 , 1015 , 1016
# 4  1006 - CONSTRUÇAO, REFORMA E AMPLIAÇAO DE PONT...
#
#   motivo_impedimento_plano_acao  valor_custeio_plano_acao  \
# 0                          None                       0.0
# 1                          None                       0.0
# 2                          None                       0.0
# 3                          None                       0.0
# 4                          None                       0.0
#
#    valor_investimento_plano_acao  id_programa
# 0                       800000.0           12
# 1                       342449.0           12
# 2                       200000.0           12
# 3                      2066010.0           12
# 4                      2066010.0           12

# %% [markdown]
# ### Análises e Verificações

# %% [markdown]
# #### Verificação se existem registros DUPLICADOS

# %%
# Verificação se existem registros DUPLICADOS

assert df_paes_raw.duplicated(subset=['id_plano_acao', 'codigo_plano_acao']).sum() == 0, "Existem registros DUPLICADOS"

# %% [markdown]
# #### Exporta o dataframe para Excel

# %%
# Exporta o dataframe para Excel

df_paes_raw.to_excel('trans_especiais_2022_2024.xlsx', index=False)

# %%
df_paes_raw = pd.read_excel('trans_especiais_2022_2024.xlsx', dtype=str)
df_paes_raw.head()

# %% [markdown]
# #### a) Top 10 parlamentares por quantidade de emendas, para cada ano.

# %%
# a) Top 10 parlamentares por quantidade de emendas, para cada ano.
# prompt: baseado no dataframe df_paes_raw, gere 03 gráficos de qtd de emendas por nome_parlamentar_emenda_plano_acao, um para cada ano_emenda_parlamentar_plano_acao.
# O gráfico deve ser de barras horizontais, com o nome do parlamentar no eixo Y, com barras agrupadas representando as quantidades de cada ano.
# Ordene por qtd de emendas do maior para o menor, e exiba apenas os top 10. Exiba cada gráfico em um quadrante e varie as cores das barras para cada ano.


# Convertendo a coluna 'ano_emenda_parlamentar_plano_acao' para numérico
df_paes_raw['ano_emenda_parlamentar_plano_acao'] = pd.to_numeric(df_paes_raw['ano_emenda_parlamentar_plano_acao'], errors='coerce')

# Agrupando os dados e ordenando
emendas_por_parlamentar = df_paes_raw.groupby(['nome_parlamentar_emenda_plano_acao', 'ano_emenda_parlamentar_plano_acao']).size().reset_index(name='quantidade')
emendas_por_parlamentar = emendas_por_parlamentar.sort_values(['ano_emenda_parlamentar_plano_acao', 'quantidade'], ascending=[True, False])

# Criando a figura e os eixos
fig, axes = plt.subplots(1, 3, figsize=(20, 10), sharey=True)
fig.suptitle('Quantidade de Emendas por Parlamentar (Top 10)', fontsize=16)

max_value = emendas_por_parlamentar['quantidade'].max()
anos = emendas_por_parlamentar['ano_emenda_parlamentar_plano_acao'].unique()
cores = ['skyblue', 'lightcoral', 'lightgreen']

for i, ano in enumerate(anos):
  ax = axes[i]
  df_ano = emendas_por_parlamentar[emendas_por_parlamentar['ano_emenda_parlamentar_plano_acao'] == ano].head(10)

  sns.barplot(x='quantidade', y='nome_parlamentar_emenda_plano_acao', data=df_ano, ax=ax, color=cores[i], orient='h')

  ax.set_title(f'Ano: {int(ano)}', fontsize=14)
  ax.set_xlabel('Quantidade de Emendas', fontsize=12)
  ax.set_ylabel('Nome do Parlamentar', fontsize=12)
  ax.set_xlim(0, max_value) # mantém a mesma escala de valores entre os anos

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Tirando a prova

df_paes_agrupado = (df_paes_raw.groupby(['nome_parlamentar_emenda_plano_acao', 'ano_emenda_parlamentar_plano_acao'])
.agg({'numero_emenda_parlamentar_plano_acao': 'count', 'valor_custeio_plano_acao': 'sum', 'valor_investimento_plano_acao': 'sum'})
.reset_index())

df_paes_agrupado.loc[df_paes_agrupado['ano_emenda_parlamentar_plano_acao'] == 2022].sort_values('numero_emenda_parlamentar_plano_acao', ascending=False).head(10)
# Out:
#      nome_parlamentar_emenda_plano_acao  ano_emenda_parlamentar_plano_acao  \
# 252                Charlles Evangelista                               2022
# 83                            Alê Silva                               2022
# 1487                  Vilson da Fetaemg                               2022
# 500                      Expedito Netto                               2022
# 1088                      Nereu Crispim                               2022
# 915                   Luiz Carlos Motta                               2022
# 695                               Irajá                               2022
# 1232              Policial Katia Sastre                               2022
# 842                         Kátia Abreu                               2022
# 1120                     Onyx Lorenzoni                               2022
#
#       numero_emenda_parlamentar_plano_acao  valor_custeio_plano_acao  \
# 252                                     76                       0.0
# 83                                      69                 3249680.0
# 1487                                    69                 1320000.0
# 500                                     68                 6050636.0
# 1088                                    66                 1229000.0
# 915                                     61                       0.0
# 695                                     59                       0.0
# 1232                                    57                       0.0
# 842                                     56                       0.0
# 1120                                    55                       0.0
#
#       valor_investimento_plano_acao
# 252                       8719681.0
# 83                        6090000.0
# 1487                      7879682.0
# 500                      15774046.0
# 1088                      7500000.0
# 915                       8819682.0
# 695                       8800000.0
# 1232                      8719682.0
# 842                       9119682.0
# 1120                      8819682.0

# %% [markdown]
# #### b) Top 10 parlamentares por valor de investimento, para cada ano

# %%
# b) Top 10 parlamentares por valor de investimento, para cada ano

# Obtem o valor máximo de 'valor_investimento_plano_acao' independente do ano
max_value = df_paes_agrupado['valor_investimento_plano_acao'].max()

# Criando a figura e os eixos
fig, axes = plt.subplots(1, 3, figsize=(20, 10), sharey=True)
fig.suptitle('Quantidade de Emendas por Parlamentar (Top 10)', fontsize=16)

for i, ano in enumerate(anos):
  ax = axes[i]
  df_ano = df_paes_agrupado.loc[df_paes_agrupado['ano_emenda_parlamentar_plano_acao'] == ano].sort_values('valor_investimento_plano_acao', ascending=False).head(10)

  sns.barplot(x='valor_investimento_plano_acao', y='nome_parlamentar_emenda_plano_acao', data=df_ano, ax=ax, color=cores[i], orient='h')

  ax.set_title(f'Ano: {int(ano)}', fontsize=14)
  ax.set_xlabel('Valor de Investimento', fontsize=12)
  ax.set_ylabel('Nome do Parlamentar', fontsize=12)
  ax.set_xlim(0, max_value) # mantém a mesma escala de valores entre os anos
  ax.xaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# #### Requisição a API - Deputados Federais
# - Fonte: Câmara dos Deputados

# %% [markdown]
# ##### Obtendo os dados básicos de Deputados Federais

# %%
# Dados sintéticos

api_url = "https://dadosabertos.camara.leg.br/api/v2/deputados"
qtd_pgs = 2
qtd_por_pag = 1000
df_dep_sint = pd.DataFrame()
for page in range(1, qtd_pgs+1):
  api_params = {
      'idLegislatura': '56,57',
      'itens': qtd_por_pag,
      'pagina': page,
  }
  result = api_request("GET", api_url, params=api_params)
  df_result = pd.DataFrame.from_dict(result['dados'], orient='columns')
  df_dep_sint = pd.concat([df_dep_sint, df_result])

print(f"Total de linhas: {len(df_dep_sint)}")
df_dep_sint.head()
# Out:
# Total de linhas: 1746
#        id                                                uri            nome  \
# 0  220593  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 1  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 2  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 3  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 4  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
#
#   siglaPartido                                         uriPartido siglaUf  \
# 0           PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1          PHS  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 2           PR  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 3           PL  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 4          PSC  https://dadosabertos.camara.leg.br/api/v2/part...      BA
#
#    idLegislatura                                            urlFoto email
# 0             57  https://www.camara.leg.br/internet/deputado/ba...  None
# 1             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 2             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 3             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 4             56  https://www.camara.leg.br/internet/deputado/ba...  None

# %% [markdown]
# ##### Aplicando a normalização do nome do deputado

# %%
# Tratando o nome do Deputado

df_dep_sint['nome_tratado'] = df_dep_sint['nome'].apply(lambda x: unidecode(x.strip()).upper())
df_dep_sint.head()
# Out:
#        id                                                uri            nome  \
# 0  220593  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 1  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 2  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 3  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
# 4  204554  https://dadosabertos.camara.leg.br/api/v2/depu...  Abílio Santana
#
#   siglaPartido                                         uriPartido siglaUf  \
# 0           PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1          PHS  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 2           PR  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 3           PL  https://dadosabertos.camara.leg.br/api/v2/part...      BA
# 4          PSC  https://dadosabertos.camara.leg.br/api/v2/part...      BA
#
#    idLegislatura                                            urlFoto email  \
# 0             57  https://www.camara.leg.br/internet/deputado/ba...  None
# 1             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 2             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 3             56  https://www.camara.leg.br/internet/deputado/ba...  None
# 4             56  https://www.camara.leg.br/internet/deputado/ba...  None
#
#      nome_tratado
# 0  ABILIO BRUNINI
# 1  ABILIO SANTANA
# 2  ABILIO SANTANA
# 3  ABILIO SANTANA
# 4  ABILIO SANTANA

# %% [markdown]
# #### Obtendo detalhamento dos Deputados Federais - Fonte: Câmara dos Deputados

# %%
# %%time
# Obtendo detalhamento dos Deputados Federais - Fonte: Câmara dos Deputados

df_dep_raw = pd.DataFrame()
urls = df_dep_sint['uri'].unique()

for i, url in enumerate(urls):
  result = api_request("GET", url)
  df_result = pd.json_normalize(result['dados'])
  df_dep_raw = pd.concat([df_dep_raw, df_result])
  if i % 50 == 0:
    print(f"{i+1:>5} de {len(urls)}")

print(f"\nTotal de linhas: {len(df_dep_raw)}")
df_dep_raw.head()
# Out:
#     1 de 513
#    51 de 513
#   101 de 513
#   151 de 513
#   201 de 513
#   251 de 513
#   301 de 513
#   351 de 513
#   401 de 513
#   451 de 513
#   501 de 513
#
# Total de linhas: 513
# CPU times: user 5.29 s, sys: 467 ms, total: 5.75 s
# Wall time: 4min 27s
#        id                                                uri  \
# 0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0  220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0  221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0  204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0  204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                         nomeCivil          cpf sexo urlWebsite  \
# 0    ACÁCIO DA SILVA FAVACHO NETO  74287028287    M       None
# 0  ADAIL JOSÉ FIGUEIREDO PINHEIRO  77267796249    M       None
# 0        ADILSON BARROSO OLIVEIRA  05585378805    M       None
# 0     ADOLFO VIANA DE CASTRO NETO  80123848504    M       None
# 0          ADRIANA MIGUEL VENTURA  12519851813    F       None
#
#                                           redeSocial dataNascimento  \
# 0  [https://twitter.com/acaciofavacho, https://ww...     1983-09-28
# 0  [https://twitter.com/adailfilhoam?s=21&t=O_eoT...     1992-02-16
# 0                                                 []     1964-06-14
# 0                                                 []     1981-02-02
# 0  [https://twitter.com/adriventurasp, https://ww...     1969-03-06
#
#   dataFalecimento ufNascimento municipioNascimento         escolaridade  \
# 0            None           AP              Macapá             Superior
# 0            None           AM              Manaus  Superior Incompleto
# 0            None           MG         Minas Novas             Superior
# 0            None           BA            Salvador             Superior
# 0            None           SP           São Paulo            Doutorado
#
#    ultimoStatus.id                                   ultimoStatus.uri  \
# 0           204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0           220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0           221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0           204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 0           204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#   ultimoStatus.nome ultimoStatus.siglaPartido ultimoStatus.uriPartido  \
# 0    Acácio Favacho                       MDB                    None
# 0       Adail Filho              REPUBLICANOS                    None
# 0   Adilson Barroso                        PL                    None
# 0      Adolfo Viana                      PSDB                    None
# 0   Adriana Ventura                      NOVO                    None
#
#   ultimoStatus.siglaUf  ultimoStatus.idLegislatura  \
# 0                   AP                          57
# 0                   AM                          57
# 0                   SP                          57
# 0                   BA                          57
# 0                   SP                          57
#
#                                 ultimoStatus.urlFoto ultimoStatus.email  \
# 0  https://www.camara.leg.br/internet/deputado/ba...               None
# 0  https://www.camara.leg.br/internet/deputado/ba...               None
# 0  https://www.camara.leg.br/internet/deputado/ba...               None
# 0  https://www.camara.leg.br/internet/deputado/ba...               None
# 0  https://www.camara.leg.br/internet/deputado/ba...               None
#
#   ultimoStatus.data ultimoStatus.nomeEleitoral ultimoStatus.gabinete.nome  \
# 0        2023-02-01             Acácio Favacho                        414
# 0        2023-02-01                Adail Filho                        531
# 0        2024-03-21            Adilson Barroso                        750
# 0        2023-02-01               Adolfo Viana                        911
# 0        2023-02-01            Adriana Ventura                        802
#
#   ultimoStatus.gabinete.predio ultimoStatus.gabinete.sala  \
# 0                            4                        414
# 0                            4                        531
# 0                            4                        750
# 0                            4                        911
# 0                            4                        802
#
#   ultimoStatus.gabinete.andar ultimoStatus.gabinete.telefone  \
# 0                           4                      3215-5414
# 0                           5                      3215-5531
# 0                           7                      3215-5750
# 0                           9                      3215-5911
# 0                           8                      3215-5802
#
#         ultimoStatus.gabinete.email ultimoStatus.situacao  \
# 0   dep.acaciofavacho@camara.leg.br             Exercício
# 0      dep.adailfilho@camara.leg.br             Exercício
# 0  dep.adilsonbarroso@camara.leg.br             Exercício
# 0     dep.adolfoviana@camara.leg.br             Exercício
# 0  dep.adrianaventura@camara.leg.br             Exercício
#
#   ultimoStatus.condicaoEleitoral ultimoStatus.descricaoStatus
# 0                        Titular                         None
# 0                        Titular                         None
# 0                       Suplente                         None
# 0                        Titular                         None
# 0                        Titular                         None

# %%
df_dep_raw.to_csv('deputados.csv', index=False)

# %%
df_dep_raw = pd.read_csv('deputados.csv', dtype=str)
df_dep_raw.head()
# Out:
#        id                                                uri  \
# 0  204379  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1  220714  https://dadosabertos.camara.leg.br/api/v2/depu...
# 2  221328  https://dadosabertos.camara.leg.br/api/v2/depu...
# 3  204560  https://dadosabertos.camara.leg.br/api/v2/depu...
# 4  204528  https://dadosabertos.camara.leg.br/api/v2/depu...
#
#                         nomeCivil          cpf sexo urlWebsite  \
# 0    ACÁCIO DA SILVA FAVACHO NETO  74287028287    M        NaN
# 1  ADAIL JOSÉ FIGUEIREDO PINHEIRO  77267796249    M        NaN
# 2        ADILSON BARROSO OLIVEIRA  05585378805    M        NaN
# 3     ADOLFO VIANA DE CASTRO NETO  80123848504    M        NaN
# 4          ADRIANA MIGUEL VENTURA  12519851813    F        NaN
#
#                                           redeSocial dataNascimento  \
# 0  ['https://twitter.com/acaciofavacho', 'https:/...     1983-09-28
# 1  ['https://twitter.com/adailfilhoam?s=21&t=O_eo...     1992-02-16
# 2                                                 []     1964-06-14
# 3                                                 []     1981-02-02
# 4  ['https://twitter.com/adriventurasp', 'https:/...     1969-03-06
#
#   dataFalecimento ufNascimento  ... ultimoStatus.nomeEleitoral  \
# 0             NaN           AP  ...             Acácio Favacho
# 1             NaN           AM  ...                Adail Filho
# 2             NaN           MG  ...            Adilson Barroso
# 3             NaN           BA  ...               Adolfo Viana
# 4             NaN           SP  ...            Adriana Ventura
#
#   ultimoStatus.gabinete.nome ultimoStatus.gabinete.predio  \
# 0                        414                            4
# 1                        531                            4
# 2                        750                            4
# 3                        911                            4
# 4                        802                            4
#
#   ultimoStatus.gabinete.sala ultimoStatus.gabinete.andar  \
# 0                        414                           4
# 1                        531                           5
# 2                        750                           7
# 3                        911                           9
# 4                        802                           8
#
#   ultimoStatus.gabinete.telefone       ultimoStatus.gabinete.email  \
# 0                      3215-5414   dep.acaciofavacho@camara.leg.br
# 1                      3215-5531      dep.adailfilho@camara.leg.br
# 2                      3215-5750  dep.adilsonbarroso@camara.leg.br
# 3                      3215-5911     dep.adolfoviana@camara.leg.br
# 4                      3215-5802  dep.adrianaventura@camara.leg.br
#
#   ultimoStatus.situacao ultimoStatus.condicaoEleitoral  \
# 0             Exercício                        Titular
# 1             Exercício                        Titular
# 2             Exercício                       Suplente
# 3             Exercício                        Titular
# 4             Exercício                        Titular
#
#   ultimoStatus.descricaoStatus
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Requisição a API - Senadores Federais
# - Fonte: Senado Federal

# %% [markdown]
# ##### Dados básicos dos senadores

# %%
# URL: https://legis.senado.leg.br/dadosabertos/senador/lista/legislatura/56/57?v=4

lst_legislaturas = ['56', '57']
api_url = "https://legis.senado.leg.br/dadosabertos/senador/lista/legislatura/" + "/".join(lst_legislaturas)
api_params = {'v': 4}
api_hearder = {'Accept': 'application/json'}
result = api_request("GET", api_url, params=api_params, headers=api_hearder)

# %%
result

# %%
df_sen_parlamentares = pd.json_normalize(result,
                                 record_path=['ListaParlamentarLegislatura','Parlamentares','Parlamentar'])
print("Total de registros:", len(df_sen_parlamentares))
df_sen_parlamentares = df_sen_parlamentares.explode('Mandatos.Mandato')
print("Total de registros:", len(df_sen_parlamentares))
df_sen_parlamentares.columns = df_sen_parlamentares.columns.str.split('.').str[-1]
df_sen_parlamentares.rename(columns={'UfParlamentar': 'UfPessoal'}, inplace=True)
df_sen_parlamentares = df_sen_parlamentares.reset_index(drop=True)
df_sen_parlamentares.head()
# Out:
# Total de registros: 318
# Total de registros: 327
#   CodigoParlamentar           NomeParlamentar   NomeCompletoParlamentar  \
# 0              5573             Abel Rebouças    Abel Rebouças São José
# 1              4981              Acir Gurgacz       Acir Marcos Gurgacz
# 2              5918             Adilson Gomes       Adilson Gomes Silva
# 3              5625  Adilson Silva dos Santos  Adilson Silva dos Santos
# 4              6382          Adrian da Blukit       Adrian Rogers Censi
#
#   SexoParlamentar FormaTratamento SiglaPartidoParlamentar  \
# 0       Masculino        Senador                      PDT
# 1       Masculino        Senador                      PDT
# 2       Masculino        Senador                      NaN
# 3       Masculino        Senador                      PEN
# 4       Masculino        Senador                      NaN
#
#                                              Mandato CodigoPublicoNaLegAtual  \
# 0  {'CodigoMandato': '492', 'UfParlamentar': 'BA'...                     NaN
# 1  {'CodigoMandato': '515', 'UfParlamentar': 'RO'...                     916
# 2  {'CodigoMandato': '526', 'UfParlamentar': 'PE'...                     NaN
# 3  {'CodigoMandato': '497', 'UfParlamentar': 'RS'...                     NaN
# 4  {'CodigoMandato': '613', 'UfParlamentar': 'SC'...                     NaN
#
#                                   UrlFotoParlamentar  \
# 0                                                NaN
# 1  http://www.senado.leg.br/senadores/img/fotos-o...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 UrlPaginaParlamentar  \
# 0                                                NaN
# 1  http://www25.senado.leg.br/web/senadores/senad...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#            UrlPaginaParticular               EmailParlamentar UfPessoal
# 0                          NaN                            NaN       NaN
# 1  https://acirgurgacz.com.br/  sen.acirgurgacz@senado.leg.br       NaN
# 2                          NaN                            NaN       NaN
# 3                          NaN                            NaN       NaN
# 4                          NaN                            NaN       NaN

# %% [markdown]
# ##### Dados de mandatos dos senadores

# %%
df_sen_mandatos = pd.json_normalize(df_sen_parlamentares['Mandato'])
print(df_sen_mandatos.shape)
df_sen_mandatos = df_sen_mandatos.reset_index(drop=True)
df_sen_mandatos.head()
# Out:
# (327, 14)
#   CodigoMandato UfParlamentar DescricaoParticipacao  \
# 0           492            BA           1º Suplente
# 1           515            RO               Titular
# 2           526            PE           2º Suplente
# 3           497            RS           2º Suplente
# 4           613            SC           2º Suplente
#
#   PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 0                                             55
# 1                                             55
# 2                                             56
# 3                                             55
# 4                                             57
#
#   PrimeiraLegislaturaDoMandato.DataInicio  \
# 0                              2015-02-01
# 1                              2015-02-01
# 2                              2019-02-01
# 3                              2015-02-01
# 4                              2023-02-01
#
#   PrimeiraLegislaturaDoMandato.DataFim  \
# 0                           2019-01-31
# 1                           2019-01-31
# 2                           2023-01-31
# 3                           2019-01-31
# 4                           2027-01-31
#
#   SegundaLegislaturaDoMandato.NumeroLegislatura  \
# 0                                            56
# 1                                            56
# 2                                            57
# 3                                            56
# 4                                            58
#
#   SegundaLegislaturaDoMandato.DataInicio SegundaLegislaturaDoMandato.DataFim  \
# 0                             2019-02-01                          2023-01-31
# 1                             2019-02-01                          2023-01-31
# 2                             2023-02-01                          2027-01-31
# 3                             2019-02-01                          2023-01-31
# 4                             2027-02-01                          2031-01-31
#
#   Titular.DescricaoParticipacao Titular.CodigoParlamentar  \
# 0                       Titular                      5523
# 1                           NaN                       NaN
# 2                       Titular                      4545
# 3                       Titular                      5533
# 4                       Titular                      6342
#
#   Titular.NomeParlamentar                                 Suplentes.Suplente  \
# 0            Otto Alencar  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 1                     NaN  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 2      Jarbas Vasconcelos  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 3          Lasier Martins  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 4              Jorge Seif  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#                                 Exercicios.Exercicio
# 0                                                NaN
# 1  [{'CodigoExercicio': '2810', 'DataInicio': '20...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# ##### Dados completos senadores

# %%
df_senadores = pd.concat([df_sen_parlamentares, df_sen_mandatos], axis=1)
df_senadores.head()
# Out:
#   CodigoParlamentar           NomeParlamentar   NomeCompletoParlamentar  \
# 0              5573             Abel Rebouças    Abel Rebouças São José
# 1              4981              Acir Gurgacz       Acir Marcos Gurgacz
# 2              5918             Adilson Gomes       Adilson Gomes Silva
# 3              5625  Adilson Silva dos Santos  Adilson Silva dos Santos
# 4              6382          Adrian da Blukit       Adrian Rogers Censi
#
#   SexoParlamentar FormaTratamento SiglaPartidoParlamentar  \
# 0       Masculino        Senador                      PDT
# 1       Masculino        Senador                      PDT
# 2       Masculino        Senador                      NaN
# 3       Masculino        Senador                      PEN
# 4       Masculino        Senador                      NaN
#
#                                              Mandato CodigoPublicoNaLegAtual  \
# 0  {'CodigoMandato': '492', 'UfParlamentar': 'BA'...                     NaN
# 1  {'CodigoMandato': '515', 'UfParlamentar': 'RO'...                     916
# 2  {'CodigoMandato': '526', 'UfParlamentar': 'PE'...                     NaN
# 3  {'CodigoMandato': '497', 'UfParlamentar': 'RS'...                     NaN
# 4  {'CodigoMandato': '613', 'UfParlamentar': 'SC'...                     NaN
#
#                                   UrlFotoParlamentar  \
# 0                                                NaN
# 1  http://www.senado.leg.br/senadores/img/fotos-o...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 UrlPaginaParlamentar  \
# 0                                                NaN
# 1  http://www25.senado.leg.br/web/senadores/senad...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#            UrlPaginaParticular               EmailParlamentar UfPessoal  \
# 0                          NaN                            NaN       NaN
# 1  https://acirgurgacz.com.br/  sen.acirgurgacz@senado.leg.br       NaN
# 2                          NaN                            NaN       NaN
# 3                          NaN                            NaN       NaN
# 4                          NaN                            NaN       NaN
#
#   CodigoMandato UfParlamentar DescricaoParticipacao  \
# 0           492            BA           1º Suplente
# 1           515            RO               Titular
# 2           526            PE           2º Suplente
# 3           497            RS           2º Suplente
# 4           613            SC           2º Suplente
#
#   PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 0                                             55
# 1                                             55
# 2                                             56
# 3                                             55
# 4                                             57
#
#   PrimeiraLegislaturaDoMandato.DataInicio  \
# 0                              2015-02-01
# 1                              2015-02-01
# 2                              2019-02-01
# 3                              2015-02-01
# 4                              2023-02-01
#
#   PrimeiraLegislaturaDoMandato.DataFim  \
# 0                           2019-01-31
# 1                           2019-01-31
# 2                           2023-01-31
# 3                           2019-01-31
# 4                           2027-01-31
#
#   SegundaLegislaturaDoMandato.NumeroLegislatura  \
# 0                                            56
# 1                                            56
# 2                                            57
# 3                                            56
# 4                                            58
#
#   SegundaLegislaturaDoMandato.DataInicio SegundaLegislaturaDoMandato.DataFim  \
# 0                             2019-02-01                          2023-01-31
# 1                             2019-02-01                          2023-01-31
# 2                             2023-02-01                          2027-01-31
# 3                             2019-02-01                          2023-01-31
# 4                             2027-02-01                          2031-01-31
#
#   Titular.DescricaoParticipacao Titular.CodigoParlamentar  \
# 0                       Titular                      5523
# 1                           NaN                       NaN
# 2                       Titular                      4545
# 3                       Titular                      5533
# 4                       Titular                      6342
#
#   Titular.NomeParlamentar                                 Suplentes.Suplente  \
# 0            Otto Alencar  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 1                     NaN  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 2      Jarbas Vasconcelos  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 3          Lasier Martins  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 4              Jorge Seif  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#                                 Exercicios.Exercicio
# 0                                                NaN
# 1  [{'CodigoExercicio': '2810', 'DataInicio': '20...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Valida a Uf do Parlamentar

df_senadores['UfParlamentar'].value_counts(dropna=False)

# %%
# Salva os dados

df_senadores.to_csv('senadores.csv', index=False)

# %% [markdown]
# ##### Verificação 01
# > verifica se há algum senador na coluna `Titular.NomeParlamentar` que não está contido na coluna `NomeParlamentar`

# %%
lst_sen_titulares = df_senadores['Titular.NomeParlamentar'].sort_values().unique()
for i, titular in enumerate(lst_sen_titulares):
  try:
    df_senadores['NomeParlamentar'].sort_values().unique().tolist().index(titular)
  except ValueError:
    print(f"{i+1:>5} - {titular} não existe na coluna 'NomeParlamentar'")
# Out:
#   105 - nan não existe na coluna 'NomeParlamentar'

# %% [markdown]
# ##### Obtendo Dados de Senadores Afastados

# %%
# Senadores Afastados

api_url = "https://legis.senado.leg.br/dadosabertos/senador/afastados"
result = api_request("GET", api_url, resp_type='text')
df_senadores_afastados = pd.read_xml(StringIO(result),  xpath=".//Parlamentar/IdentificacaoParlamentar")
print(f"Total de linhas: {len(df_senadores_afastados)}")
df_senadores_afastados.head()
# Out:
# Total de linhas: 37
#    CodigoParlamentar     NomeParlamentar         NomeCompletoParlamentar  \
# 0               6366        André Amaral  Andre Augusto Castro do Amaral
# 1                751  Arolde de Oliveira              Arolde de Oliveira
# 2               4979        Bene Camacho       Bene André Camacho Araújo
# 3               6011        Beto Martins            Jose Roberto Martins
# 4               6336      Camilo Santana      Camilo Sobreira de Santana
#
#   SexoParlamentar FormaTratamento  \
# 0       Masculino         Senador
# 1       Masculino         Senador
# 2       Masculino         Senador
# 3       Masculino         Senador
# 4       Masculino         Senador
#
#                                   UrlFotoParlamentar  \
# 0  http://www.senado.leg.br/senadores/img/fotos-o...
# 1  http://www.senado.leg.br/senadores/img/fotos-o...
# 2  http://www.senado.leg.br/senadores/img/fotos-o...
# 3  http://www.senado.leg.br/senadores/img/fotos-o...
# 4  http://www.senado.leg.br/senadores/img/fotos-o...
#
#                                 UrlPaginaParlamentar  \
# 0  http://www25.senado.leg.br/web/senadores/senad...
# 1  http://www25.senado.leg.br/web/senadores/senad...
# 2  http://www25.senado.leg.br/web/senadores/senad...
# 3  http://www25.senado.leg.br/web/senadores/senad...
# 4  http://www25.senado.leg.br/web/senadores/senad...
#
#                      EmailParlamentar SiglaPartidoParlamentar  \
# 0       sen.andreamaral@senado.leg.br                   UNIÃO
# 1  sen.aroldedeoliveira@senado.leg.br                     PSD
# 2       sen.benecamacho@senado.leg.br                     PSD
# 3       sen.betomartins@senado.leg.br                      PL
# 4     sen.camilosantana@senado.leg.br                      PT
#
#   UrlPaginaParticular UfParlamentar
# 0                None          None
# 1                None          None
# 2                None          None
# 3                None          None
# 4                None          None

# %% [markdown]
# ##### Verificação 02
# > verifica se há senadores afastados que não constam em `df_senadores`

# %%
lst_sen_afastados = df_senadores_afastados['NomeParlamentar'].sort_values().unique()
for i, titular in enumerate(lst_sen_afastados):
  try:
    df_senadores['NomeParlamentar'].sort_values().unique().tolist().index(titular)
  except ValueError:
    print(f"{i+1:>5} - {titular} não existe na coluna 'NomeParlamentar'")
else:
  df_todos_senadores = df_senadores.copy()

# %% [markdown]
# ##### Se houver, concatena os dois conjuntos de dados (Senadores + Senadores Afastados)

# %%
# Concatena os dois conjuntos de dados de Senadores

# df_todos_senadores = pd.concat([df_senadores, df_senadores_afastados])
# df_todos_senadores.head()

# %% [markdown]
# ##### Verificação 03
# > verifica os nomes duplicados

# %%
df_todos_senadores.loc[df_todos_senadores['NomeParlamentar'].duplicated(keep=False)]
# Out:
#     CodigoParlamentar      NomeParlamentar  \
# 44               6295        Carlos Fávaro
# 45               6295        Carlos Fávaro
# 70               3830      Davi Alcolumbre
# 71               3830      Davi Alcolumbre
# 101              5980    Fernando Carvalho
# 102              6384    Fernando Carvalho
# 153              5569               Josiel
# 154              5569               Josiel
# 155              5849          José Amauri
# 156              5849          José Amauri
# 224              5525            Omar Aziz
# 225              5525            Omar Aziz
# 228              5523         Otto Alencar
# 229              5523         Otto Alencar
# 235              5617     Pastor Valadares
# 236              5617     Pastor Valadares
# 275              5322              Romário
# 276              5322              Romário
# 321              1173  Wellington Fagundes
# 322              1173  Wellington Fagundes
#
#                   NomeCompletoParlamentar SexoParlamentar FormaTratamento  \
# 44         Carlos Henrique Baqueta Fávaro       Masculino        Senador
# 45         Carlos Henrique Baqueta Fávaro       Masculino        Senador
# 70        David Samuel Alcolumbre Tobelem       Masculino        Senador
# 71        David Samuel Alcolumbre Tobelem       Masculino        Senador
# 101   Fernando Luiz Prado Carvalho Junior       Masculino        Senador
# 102  Antonio Fernando Pereira de Carvalho       Masculino        Senador
# 153        Jose Samuel Alcolumbre Tobelem       Masculino        Senador
# 154        Jose Samuel Alcolumbre Tobelem       Masculino        Senador
# 155              Jose Amauri P. de Araújo       Masculino        Senador
# 156              Jose Amauri P. de Araújo       Masculino        Senador
# 224                  Omar José Abdel Aziz       Masculino        Senador
# 225                  Omar José Abdel Aziz       Masculino        Senador
# 228      Otto Roberto Mendonça de Alencar       Masculino        Senador
# 229      Otto Roberto Mendonça de Alencar       Masculino        Senador
# 235              Sebastião Valadares Neto       Masculino        Senador
# 236              Sebastião Valadares Neto       Masculino        Senador
# 275                Romario de Souza Faria       Masculino        Senador
# 276                Romario de Souza Faria       Masculino        Senador
# 321           Wellington Antonio Fagundes       Masculino        Senador
# 322           Wellington Antonio Fagundes       Masculino        Senador
#
#     SiglaPartidoParlamentar  \
# 44                      PSD
# 45                      PSD
# 70                    UNIÃO
# 71                    UNIÃO
# 101                     NaN
# 102                     NaN
# 153                   UNIÃO
# 154                   UNIÃO
# 155                 PODEMOS
# 156                 PODEMOS
# 224                     PSD
# 225                     PSD
# 228                     PSD
# 229                     PSD
# 235                     PDT
# 236                     PDT
# 275                      PL
# 276                      PL
# 321                      PL
# 322                      PL
#
#                                                Mandato  \
# 44   {'CodigoMandato': '582', 'UfParlamentar': 'MT'...
# 45   {'CodigoMandato': '592', 'UfParlamentar': 'MT'...
# 70   {'CodigoMandato': '501', 'UfParlamentar': 'AP'...
# 71   {'CodigoMandato': '618', 'UfParlamentar': 'AP'...
# 101  {'CodigoMandato': '559', 'UfParlamentar': 'SE'...
# 102  {'CodigoMandato': '614', 'UfParlamentar': 'SE'...
# 153  {'CodigoMandato': '501', 'UfParlamentar': 'AP'...
# 154  {'CodigoMandato': '618', 'UfParlamentar': 'AP'...
# 155  {'CodigoMandato': '496', 'UfParlamentar': 'PI'...
# 156  {'CodigoMandato': '607', 'UfParlamentar': 'PI'...
# 224  {'CodigoMandato': '493', 'UfParlamentar': 'AM'...
# 225  {'CodigoMandato': '619', 'UfParlamentar': 'AM'...
# 228  {'CodigoMandato': '492', 'UfParlamentar': 'BA'...
# 229  {'CodigoMandato': '622', 'UfParlamentar': 'BA'...
# 235  {'CodigoMandato': '515', 'UfParlamentar': 'RO'...
# 236  {'CodigoMandato': '610', 'UfParlamentar': 'RO'...
# 275  {'CodigoMandato': '509', 'UfParlamentar': 'RJ'...
# 276  {'CodigoMandato': '620', 'UfParlamentar': 'RJ'...
# 321  {'CodigoMandato': '506', 'UfParlamentar': 'MT'...
# 322  {'CodigoMandato': '621', 'UfParlamentar': 'MT'...
#
#     CodigoPublicoNaLegAtual  \
# 44                      945
# 45                      945
# 70                      834
# 71                      834
# 101                     NaN
# 102                     NaN
# 153                     NaN
# 154                     NaN
# 155                     NaN
# 156                     NaN
# 224                     803
# 225                     803
# 228                     831
# 229                     831
# 235                     NaN
# 236                     NaN
# 275                     840
# 276                     840
# 321                     842
# 322                     842
#
#                                     UrlFotoParlamentar  \
# 44   http://www.senado.leg.br/senadores/img/fotos-o...
# 45   http://www.senado.leg.br/senadores/img/fotos-o...
# 70   http://www.senado.leg.br/senadores/img/fotos-o...
# 71   http://www.senado.leg.br/senadores/img/fotos-o...
# 101                                                NaN
# 102                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155  http://www.senado.leg.br/senadores/img/fotos-o...
# 156  http://www.senado.leg.br/senadores/img/fotos-o...
# 224  http://www.senado.leg.br/senadores/img/fotos-o...
# 225  http://www.senado.leg.br/senadores/img/fotos-o...
# 228  http://www.senado.leg.br/senadores/img/fotos-o...
# 229  http://www.senado.leg.br/senadores/img/fotos-o...
# 235  http://www.senado.leg.br/senadores/img/fotos-o...
# 236  http://www.senado.leg.br/senadores/img/fotos-o...
# 275  http://www.senado.leg.br/senadores/img/fotos-o...
# 276  http://www.senado.leg.br/senadores/img/fotos-o...
# 321  http://www.senado.leg.br/senadores/img/fotos-o...
# 322  http://www.senado.leg.br/senadores/img/fotos-o...
#
#                                   UrlPaginaParlamentar  UrlPaginaParticular  \
# 44   http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 45   http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 70   http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 71   http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 101                                                NaN                  NaN
# 102                                                NaN                  NaN
# 153                                                NaN                  NaN
# 154                                                NaN                  NaN
# 155  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 156  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 224  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 225  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 228  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 229  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 235  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 236  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 275  http://www25.senado.leg.br/web/senadores/senad...  http://romario.org/
# 276  http://www25.senado.leg.br/web/senadores/senad...  http://romario.org/
# 321  http://www25.senado.leg.br/web/senadores/senad...                  NaN
# 322  http://www25.senado.leg.br/web/senadores/senad...                  NaN
#
#                          EmailParlamentar UfPessoal CodigoMandato  \
# 44         sen.carlosfavaro@senado.leg.br       NaN           582
# 45         sen.carlosfavaro@senado.leg.br       NaN           592
# 70       sen.davialcolumbre@senado.leg.br        AP           501
# 71       sen.davialcolumbre@senado.leg.br        AP           618
# 101                                   NaN       NaN           559
# 102                                   NaN       NaN           614
# 153                                   NaN       NaN           501
# 154                                   NaN       NaN           618
# 155          sen.joseamauri@senado.leg.br       NaN           496
# 156          sen.joseamauri@senado.leg.br       NaN           607
# 224            sen.omaraziz@senado.leg.br        AM           493
# 225            sen.omaraziz@senado.leg.br        AM           619
# 228         sen.ottoalencar@senado.leg.br        BA           492
# 229         sen.ottoalencar@senado.leg.br        BA           622
# 235       pastor.valadares@senador.leg.br       NaN           515
# 236       pastor.valadares@senador.leg.br       NaN           610
# 275             sen.romario@senado.leg.br        RJ           509
# 276             sen.romario@senado.leg.br        RJ           620
# 321  sen.wellingtonfagundes@senado.leg.br        MT           506
# 322  sen.wellingtonfagundes@senado.leg.br        MT           621
#
#     UfParlamentar DescricaoParticipacao  \
# 44             MT               Titular
# 45             MT               Titular
# 70             AP               Titular
# 71             AP               Titular
# 101            SE           1º Suplente
# 102            SE           2º Suplente
# 153            AP           1º Suplente
# 154            AP           1º Suplente
# 155            PI           1º Suplente
# 156            PI           2º Suplente
# 224            AM               Titular
# 225            AM               Titular
# 228            BA               Titular
# 229            BA               Titular
# 235            RO           2º Suplente
# 236            RO           1º Suplente
# 275            RJ               Titular
# 276            RJ               Titular
# 321            MT               Titular
# 322            MT               Titular
#
#     PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 44                                              56
# 45                                              56
# 70                                              55
# 71                                              57
# 101                                             56
# 102                                             57
# 153                                             55
# 154                                             57
# 155                                             55
# 156                                             57
# 224                                             55
# 225                                             57
# 228                                             55
# 229                                             57
# 235                                             55
# 236                                             57
# 275                                             55
# 276                                             57
# 321                                             55
# 322                                             57
#
#     PrimeiraLegislaturaDoMandato.DataInicio  \
# 44                               2019-02-01
# 45                               2019-02-01
# 70                               2015-02-01
# 71                               2023-02-01
# 101                              2019-02-01
# 102                              2023-02-01
# 153                              2015-02-01
# 154                              2023-02-01
# 155                              2015-02-01
# 156                              2023-02-01
# 224                              2015-02-01
# 225                              2023-02-01
# 228                              2015-02-01
# 229                              2023-02-01
# 235                              2015-02-01
# 236                              2023-02-01
# 275                              2015-02-01
# 276                              2023-02-01
# 321                              2015-02-01
# 322                              2023-02-01
#
#     PrimeiraLegislaturaDoMandato.DataFim  \
# 44                            2023-01-31
# 45                            2023-01-31
# 70                            2019-01-31
# 71                            2027-01-31
# 101                           2023-01-31
# 102                           2027-01-31
# 153                           2019-01-31
# 154                           2027-01-31
# 155                           2019-01-31
# 156                           2027-01-31
# 224                           2019-01-31
# 225                           2027-01-31
# 228                           2019-01-31
# 229                           2027-01-31
# 235                           2019-01-31
# 236                           2027-01-31
# 275                           2019-01-31
# 276                           2027-01-31
# 321                           2019-01-31
# 322                           2027-01-31
#
#     SegundaLegislaturaDoMandato.NumeroLegislatura  \
# 44                                             57
# 45                                             57
# 70                                             56
# 71                                             58
# 101                                            57
# 102                                            58
# 153                                            56
# 154                                            58
# 155                                            56
# 156                                            58
# 224                                            56
# 225                                            58
# 228                                            56
# 229                                            58
# 235                                            56
# 236                                            58
# 275                                            56
# 276                                            58
# 321                                            56
# 322                                            58
#
#     SegundaLegislaturaDoMandato.DataInicio  \
# 44                              2023-02-01
# 45                              2023-02-01
# 70                              2019-02-01
# 71                              2027-02-01
# 101                             2023-02-01
# 102                             2027-02-01
# 153                             2019-02-01
# 154                             2027-02-01
# 155                             2019-02-01
# 156                             2027-02-01
# 224                             2019-02-01
# 225                             2027-02-01
# 228                             2019-02-01
# 229                             2027-02-01
# 235                             2019-02-01
# 236                             2027-02-01
# 275                             2019-02-01
# 276                             2027-02-01
# 321                             2019-02-01
# 322                             2027-02-01
#
#     SegundaLegislaturaDoMandato.DataFim Titular.DescricaoParticipacao  \
# 44                           2027-01-31                           NaN
# 45                           2027-01-31                           NaN
# 70                           2023-01-31                           NaN
# 71                           2031-01-31                           NaN
# 101                          2027-01-31                       Titular
# 102                          2031-01-31                       Titular
# 153                          2023-01-31                       Titular
# 154                          2031-01-31                       Titular
# 155                          2023-01-31                       Titular
# 156                          2031-01-31                       Titular
# 224                          2023-01-31                           NaN
# 225                          2031-01-31                           NaN
# 228                          2023-01-31                           NaN
# 229                          2031-01-31                           NaN
# 235                          2023-01-31                       Titular
# 236                          2031-01-31                       Titular
# 275                          2023-01-31                           NaN
# 276                          2031-01-31                           NaN
# 321                          2023-01-31                           NaN
# 322                          2031-01-31                           NaN
#
#     Titular.CodigoParlamentar Titular.NomeParlamentar  \
# 44                        NaN                     NaN
# 45                        NaN                     NaN
# 70                        NaN                     NaN
# 71                        NaN                     NaN
# 101                      5982       Alessandro Vieira
# 102                      4811        Laércio Oliveira
# 153                      3830         Davi Alcolumbre
# 154                      3830         Davi Alcolumbre
# 155                      5531           Elmano Férrer
# 156                      5016         Wellington Dias
# 224                       NaN                     NaN
# 225                       NaN                     NaN
# 228                       NaN                     NaN
# 229                       NaN                     NaN
# 235                      4981            Acir Gurgacz
# 236                      6340         Jaime Bagattoli
# 275                       NaN                     NaN
# 276                       NaN                     NaN
# 321                       NaN                     NaN
# 322                       NaN                     NaN
#
#                                     Suplentes.Suplente  \
# 44                                                 NaN
# 45   [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 70   [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 71   [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 101  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 102  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 153  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 154  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 155  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 156  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 224  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 225  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 228  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 229  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 235  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 236  [{'DescricaoParticipacao': '2º Suplente', 'Cod...
# 275  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 276  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 321  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 322  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#                                   Exercicios.Exercicio
# 44   [{'CodigoExercicio': '2954', 'DataInicio': '20...
# 45   [{'CodigoExercicio': '3084', 'DataInicio': '20...
# 70   [{'CodigoExercicio': '2732', 'DataInicio': '20...
# 71   [{'CodigoExercicio': '3021', 'DataInicio': '20...
# 101                                                NaN
# 102                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155  [{'CodigoExercicio': '2857', 'DataInicio': '20...
# 156                                                NaN
# 224  [{'CodigoExercicio': '2741', 'DataInicio': '20...
# 225  [{'CodigoExercicio': '3031', 'DataInicio': '20...
# 228  [{'CodigoExercicio': '2742', 'DataInicio': '20...
# 229  [{'CodigoExercicio': '3030', 'DataInicio': '20...
# 235  [{'CodigoExercicio': '2800', 'DataInicio': '20...
# 236                                                NaN
# 275  [{'CodigoExercicio': '2746', 'DataInicio': '20...
# 276  [{'CodigoExercicio': '3029', 'DataInicio': '20...
# 321  [{'CodigoExercicio': '2753', 'DataInicio': '20...
# 322  [{'CodigoExercicio': '3072', 'DataInicio': '20...

# %% [markdown]
# ##### Havendo duplicados, mantém apenas o registro concernente à última legislatura

# %%
# Ordena os dados de senadores pelo numero da segunda Legislatura em ordem decrescente
df_todos_senadores = df_todos_senadores.sort_values(by='SegundaLegislaturaDoMandato.NumeroLegislatura', ascending=False).reset_index(drop=True)

# Deleta os registros duplicados, mantendo a primeira ocorrencia
df_todos_senadores.drop_duplicates(subset='NomeParlamentar', keep='first', inplace=True)

# Verificando novamente para ter certeza da exclução de duplicados
df_todos_senadores.loc[df_todos_senadores['NomeParlamentar'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [CodigoParlamentar, NomeParlamentar, NomeCompletoParlamentar, SexoParlamentar, FormaTratamento, SiglaPartidoParlamentar, Mandato, CodigoPublicoNaLegAtual, UrlFotoParlamentar, UrlPaginaParlamentar, UrlPaginaParticular, EmailParlamentar, UfPessoal, CodigoMandato, UfParlamentar, DescricaoParticipacao, PrimeiraLegislaturaDoMandato.NumeroLegislatura, PrimeiraLegislaturaDoMandato.DataInicio, PrimeiraLegislaturaDoMandato.DataFim, SegundaLegislaturaDoMandato.NumeroLegislatura, SegundaLegislaturaDoMandato.DataInicio, SegundaLegislaturaDoMandato.DataFim, Titular.DescricaoParticipacao, Titular.CodigoParlamentar, Titular.NomeParlamentar, Suplentes.Suplente, Exercicios.Exercicio]
# Index: []

# %%
# Análise de validação
df_todos_senadores.loc[df_todos_senadores['NomeParlamentar'] == 'Davi Alcolumbre']
# Out:
#    CodigoParlamentar  NomeParlamentar          NomeCompletoParlamentar  \
# 20              3830  Davi Alcolumbre  David Samuel Alcolumbre Tobelem
#
#    SexoParlamentar FormaTratamento SiglaPartidoParlamentar  \
# 20       Masculino        Senador                    UNIÃO
#
#                                               Mandato CodigoPublicoNaLegAtual  \
# 20  {'CodigoMandato': '618', 'UfParlamentar': 'AP'...                     834
#
#                                    UrlFotoParlamentar  \
# 20  http://www.senado.leg.br/senadores/img/fotos-o...
#
#                                  UrlPaginaParlamentar UrlPaginaParticular  \
# 20  http://www25.senado.leg.br/web/senadores/senad...                 NaN
#
#                     EmailParlamentar UfPessoal CodigoMandato UfParlamentar  \
# 20  sen.davialcolumbre@senado.leg.br        AP           618            AP
#
#    DescricaoParticipacao PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 20               Titular                                             57
#
#    PrimeiraLegislaturaDoMandato.DataInicio  \
# 20                              2023-02-01
#
#    PrimeiraLegislaturaDoMandato.DataFim  \
# 20                           2027-01-31
#
#    SegundaLegislaturaDoMandato.NumeroLegislatura  \
# 20                                            58
#
#    SegundaLegislaturaDoMandato.DataInicio SegundaLegislaturaDoMandato.DataFim  \
# 20                             2027-02-01                          2031-01-31
#
#    Titular.DescricaoParticipacao Titular.CodigoParlamentar  \
# 20                           NaN                       NaN
#
#    Titular.NomeParlamentar                                 Suplentes.Suplente  \
# 20                     NaN  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#                                  Exercicios.Exercicio
# 20  [{'CodigoExercicio': '3021', 'DataInicio': '20...

# %% [markdown]
# ##### Aplicando a normalização nos nomes dos Senadores

# %%
df_todos_senadores['nome_tratado'] = df_todos_senadores['NomeParlamentar'].apply(lambda x: unidecode(x.strip()).upper())

# %% [markdown]
# ### Inclui dados de Deputados / Senadores no conjunto de dados de Planos de Trabalho Especiais

# %% [markdown]
# ##### Preparando o dataframe de planos de ação especiais para receber dados de Parlamentares

# %%
df_paes = df_paes_raw.copy()

# %%
# Converte o a coluna 'ano_plano_acao' para numérico

df_paes['ano_plano_acao'] = pd.to_numeric(df_paes['ano_plano_acao'], errors='coerce')
df_paes['ano_plano_acao'].unique()
# Out:
# array([2023, 2024])

# %%
# Aplica o tratamento de nomes de parlamentares ao conjunto de dados de planos de ação especiais

df_paes['nome_parlamentar_tratado'] = df_paes['nome_parlamentar_emenda_plano_acao'].apply(lambda x: unidecode(x.strip()).upper())

# %%
# Verificando o nome tratado

df_paes[['nome_parlamentar_emenda_plano_acao', 'nome_parlamentar_tratado']]

# %% [markdown]
# ##### Adicionar coluna `tipo_parlamentar`

# %%
# Adiciona a coluna 'tipo_parlamentar' e Categoriza os parlamentares em Deputado|Senador

df_paes['tipo_parlamentar'] = pd.NA
df_paes.loc[df_paes['nome_parlamentar_tratado'].isin(df_dep_sint['nome_tratado'].unique()), 'tipo_parlamentar'] = 'Deputado'
df_paes.loc[df_paes['nome_parlamentar_tratado'].isin(df_todos_senadores['nome_tratado'].unique()), 'tipo_parlamentar'] = 'Senador'

# %%
#  Verificando se todas as linhas foram preenchida com algum tipo válido

df_paes['tipo_parlamentar'].value_counts(dropna=False)
# Out:
# tipo_parlamentar
# Deputado    16230
# Senador      3894
# <NA>           83
# Name: count, dtype: int64

# %%
# Já que há registros que não foram categorizados como Deputado ou Senador
#  Vamos indentificar quais são esses parlamentares no conjunto de dados de plano de ação especiais

df_paes.loc[pd.isna(df_paes['tipo_parlamentar']), 'nome_parlamentar_tratado'].unique()
# Out:
# array(['JEAN PAUL PRATES', 'DEP. ROSEANA SARNEY', 'DEP. JOSIVALDO JP'],
#       dtype=object)

# %%
# Verifica a existencia desse parlamentares nos conjuntos de dados de senadores e deputados

print(df_todos_senadores['nome_tratado'].unique().tolist().index('JEAN-PAUL PRATES'))
print(df_dep_sint['nome_tratado'].unique().tolist().index('ROSEANA SARNEY'))
print(df_dep_sint['nome_tratado'].unique().tolist().index('JOSIVALDO JP'))
# Out:
# 290
# 814
# 471

# %%
# Aplicar a correção dos nomes desses 03 parlamentares

df_paes.loc[df_paes['nome_parlamentar_tratado'] == 'JEAN PAUL PRATES', 'nome_parlamentar_tratado'] = 'JEAN-PAUL PRATES'
df_paes['nome_parlamentar_tratado'] = df_paes['nome_parlamentar_tratado'].apply( lambda x: x[5:] if x.startswith('DEP. ') else x)

# %%
# # EXECUTANDO NOVAMENTE
# Adiciona a coluna 'tipo_parlamentar' e Categoriza os parlamentares em Deputado|Senador

df_paes['tipo_parlamentar'] = pd.NA
df_paes.loc[df_paes['nome_parlamentar_tratado'].isin(df_dep_sint['nome_tratado'].unique()), 'tipo_parlamentar'] = 'Deputado'
df_paes.loc[df_paes['nome_parlamentar_tratado'].isin(df_todos_senadores['nome_tratado'].unique()), 'tipo_parlamentar'] = 'Senador'

# %%
# # EXECUTANDO NOVAMENTE
#  Verificando se todas as linhas foram preenchida com algum tipo válido

df_paes['tipo_parlamentar'].value_counts(dropna=False)
# Out:
# tipo_parlamentar
# Deputado    16246
# Senador      3961
# Name: count, dtype: int64

# %% [markdown]
# ##### Adicionar coluna `partido_sigla`

# %%
def inclui_partido_sigla(nome_parl, nomes_dep, nomes_sen):
  if nome_parl in nomes_dep:
    return df_dep_sint.loc[df_dep_sint['nome_tratado'] == nome_parl]['siglaPartido'].iloc[-1]
  elif nome_parl in nomes_sen:
    return df_todos_senadores.loc[df_todos_senadores['nome_tratado'] == nome_parl]['SiglaPartidoParlamentar'].iloc[-1]
  else:
    return pd.NA


df_paes['partido_sigla'] = df_paes['nome_parlamentar_tratado'].apply(inclui_partido_sigla, args=(df_dep_sint['nome_tratado'].unique(), df_todos_senadores['nome_tratado'].unique()))

# %%
# Validações

df_paes.loc[df_paes['tipo_parlamentar'] == 'Deputado', 'partido_sigla'].value_counts(dropna=False)
# Out:
# partido_sigla
# PL               2815
# PT               2268
# PP               2039
# PSD              1570
# UNIÃO            1419
# MDB              1417
# REPUBLICANOS     1197
# PDT               669
# PSDB              578
# PSB               544
# PODE              382
# PRD               296
# AVANTE            260
# CIDADANIA         235
# PCdoB             152
# SOLIDARIEDADE     149
# PV                100
# NOVO               46
# PSC                40
# PROS               33
# PATRIOTA           12
# PTB                10
# REDE                9
# PSOL                6
# Name: count, dtype: int64

# %% [markdown]
# ##### Adicionar coluna `url_foto_parlamentar`

# %%
def inclui_foto_parlamentar(nome_parl, nomes_dep, nomes_sen):
  if nome_parl in nomes_dep:
    return df_dep_sint.loc[df_dep_sint['nome_tratado'] == nome_parl]['urlFoto'].iloc[-1]
  elif nome_parl in nomes_sen:
    return df_todos_senadores.loc[df_todos_senadores['nome_tratado'] == nome_parl]['UrlFotoParlamentar'].iloc[-1]
  else:
    return pd.NA


df_paes['url_foto_parlamentar'] = df_paes['nome_parlamentar_tratado'].apply(inclui_foto_parlamentar, args=(df_dep_sint['nome_tratado'].unique(), df_todos_senadores['nome_tratado'].unique()))

# %%
# Validações

df_paes.loc[df_paes['tipo_parlamentar'] == 'Senador', 'url_foto_parlamentar'].value_counts(dropna=False).tail(20)
# Out:
# url_foto_parlamentar
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador6358.jpg    12
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador6331.jpg    12
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5972.jpg    11
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador4525.jpg     9
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5527.jpg     8
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5639.jpg     7
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador6008.jpg     7
# https://www.camara.leg.br/internet/deputado/bandep/220546.jpg             7
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador677.jpg      6
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador6295.jpg     6
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5322.jpg     5
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5385.jpg     5
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5942.jpg     3
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador90.jpg       3
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5537.jpg     3
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5535.jpg     2
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador581.jpg      2
# https://www.camara.leg.br/internet/deputado/bandep/220612.jpg             1
# http://www.senado.leg.br/senadores/img/fotos-oficiais/senador5979.jpg     1
# https://www.camara.leg.br/internet/deputado/bandep/178905.jpg             1
# Name: count, dtype: int64

# %% [markdown]
# ##### Adicionar coluna `uf_parlamentar`

# %%
def inclui_uf_parlamentar(nome_parl, nomes_dep, nomes_sen):
  if nome_parl in nomes_dep:
    return df_dep_sint.loc[df_dep_sint['nome_tratado'] == nome_parl]['siglaUf'].iloc[-1]
  elif nome_parl in nomes_sen:
    return df_todos_senadores.loc[df_todos_senadores['nome_tratado'] == nome_parl]['UfParlamentar'].iloc[-1]
  else:
    return pd.NA


df_paes['uf_parlamentar'] = df_paes['nome_parlamentar_tratado'].apply(inclui_uf_parlamentar, args=(df_dep_sint['nome_tratado'].unique(), df_todos_senadores['nome_tratado'].unique()))

# %%
# Validações

df_paes.loc[df_paes['tipo_parlamentar'] == 'Deputado', 'uf_parlamentar'].value_counts(dropna=False).tail(20)
# Out:
# uf_parlamentar
# PB    521
# PE    514
# CE    505
# MA    480
# PI    421
# PA    388
# RN    382
# TO    358
# RO    238
# ES    236
# RJ    222
# SE    206
# MT    158
# AL    152
# AP    125
# MS    114
# AM    106
# AC    103
# RR     83
# DF     15
# Name: count, dtype: int64

# %% [markdown]
# #### Exporta o conjunto de dados tratado

# %%
# Exporta o conjunto de dados tratado

df_paes.to_excel('trans_especiais_2023_2024_tratado.xlsx', index=False)
